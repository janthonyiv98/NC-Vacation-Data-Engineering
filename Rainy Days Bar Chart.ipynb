# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib notebook
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
from scipy.stats import linregress
from scipy import stats
from datetime import date

# %%
combined_data = pd.read_csv("combined_data.csv")
nc_coordinate_data = pd.read_csv("NC_Coordinate_Data.csv")

# %%
combined_df = pd.merge(combined_data, nc_coordinate_data, on="city_id")
combined_df.head()
# Out:
#    id city_id          name datetime  tempmax  tempmin  temp  feelslikemax  \
# 0   1    nc01  asheville,NC   1/1/23     62.8     40.3  48.1          62.8
# 1   2    nc01  asheville,NC   1/2/23     65.3     40.4  49.0          65.3
# 2   3    nc01  asheville,NC   1/3/23     64.0     49.4  57.5          64.0
# 3   4    nc01  asheville,NC   1/4/23     60.6     42.3  54.8          60.6
# 4   5    nc01  asheville,NC   1/5/23     58.2     32.8  44.8          58.2
#
#    feelslikemin  feelslike  ...              sunrise               sunset  \
# 0          40.3       48.1  ...  2023-01-01T07:39:54  2023-01-01T17:27:50
# 1          40.4       48.9  ...  2023-01-02T07:40:04  2023-01-02T17:28:37
# 2          49.4       57.5  ...  2023-01-03T07:40:12  2023-01-03T17:29:25
# 3          40.2       54.7  ...  2023-01-04T07:40:18  2023-01-04T17:30:14
# 4          32.8       44.0  ...  2023-01-05T07:40:22  2023-01-05T17:31:04
#
#    moonphase              conditions  \
# ...

# %%
del combined_df['City']
combined_df = combined_df.rename(columns={'name':'city'})
combined_df['datetime'] = pd.to_datetime(combined_df['datetime'])
# Out:
# /var/folders/_0/z435wnvn6236c4cm5wmb3_4w0000jc/T/ipykernel_81206/3704893527.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   combined_df['datetime'] = pd.to_datetime(combined_df['datetime'])

# %%
rain_df = combined_df[combined_df['icon'].str.contains('rain')]

# %%
rain_days_df = pd.DataFrame(rain_df['city'].value_counts())
rain_days_df
# Out:
#                    count
# city
# cherokee nc          181
# ocracoke nc          165
# Raleigh, NC          154
# Nags Head, NC        153
# Banner Elk, NC       152
# emerald isle, nc     144
# High Point, NC       143
# asheville,NC         142
# charlotte, nc        138
# Boone, NC            131
# Wilmington           131
# winston-salem, nc    123

# %%
x_axis = np.arange(len(rain_days_df))
plt.bar(x_axis, rain_days_df['count'])
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["Cherokee", "Ocracoke", "Raleigh", "Nags Head", "Banner Elk", "Emerald Isle", "High Point", "Asheville", "Charlotte", "Boone", "Wilmington", "Winston-Salem"], rotation="vertical")
plt.title('Number of Rainy Days in North Carolina Cities (2023)')
plt.xlabel('City')
plt.ylabel('Rainy Days')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
